# %% [markdown]
# <a href="https://colab.research.google.com/github/lastinm/ml_hw_notebooks/blob/main/%D0%A1%D0%B5%D0%BC%D0%B5%D1%81%D1%82%D1%80_3_%D0%A5%D0%B0%D0%BA%D0%B0%D1%82%D0%BE%D0%BD_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Загрузка датасета из Google Drive

# %%
from google.colab import drive

# Подключение Google Диска
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Загрузка данных
data = pd.read_csv("/content/drive/MyDrive/Data/geo-reviews-dataset-2023.tskv", sep='\t')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499999 entries, 0 to 499998
# Data columns (total 5 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Non-Null Count   Dtype
# ...

# %%
# Содержимое файла
data
# Out:
#        address=Екатеринбург, ул. Московская / ул. Волгоградская / ул. Печатников  \
# 0       address=Московская область, Электросталь, прос...
# 1       address=Краснодар, Прикубанский внутригородско...
# 2       address=Санкт-Петербург, проспект Энгельса, 11...
# 3               address=Тверь, Волоколамский проспект, 39
# 4       address=Иркутская область, Черемхово, Первомай...
# ...                                                   ...
# 499994  address=Москва, Южный административный округ, ...
# 499995  address=Москва, Южный административный округ, ...
# 499996   address=Новосибирск, Коммунистическая улица, 48А
# 499997  address=Астраханская область, Харабалинский район
# 499998  address=Астраханская область, Харабалинский район
#
#            name_ru=Московский квартал         rating=3.  \
# 0           name_ru=Продукты Ермолино         rating=5.
# 1                     name_ru=LimeFit         rating=1.
# 2                name_ru=Snow-Express         rating=4.
# ...

# %%
data.describe()
# Out:
#        address=Екатеринбург, ул. Московская / ул. Волгоградская / ул. Печатников  \
# count                                              499999
# unique                                             191924
# top                  address=Москва, Ходынский бульвар, 4
# freq                                                  340
#
#        name_ru=Московский квартал  rating=3. rubrics=Жилой комплекс  \
# count                      499999     499999                 499999
# unique                     148460        393                  32694
# top             name_ru=Пятёрочка  rating=5.      rubrics=Гостиница
# freq                         6030     389693                  42200
#
# ...
